# %%
# !whoami
# !pwd
# !which python
# Out:
# 8idiuser
# /home/beams10/8IDIUSER/.ipython-bluesky
# /home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/bin/python

# %%
# !pwd
# Out:
# /home/beams10/8IDIUSER/.ipython-bluesky

# %%
import os
import sys
path = os.path.join(
    os.environ["HOME"], 
    ".ipython-bluesky",
    "profile_bluesky",
    "startup")
sys.path.append(path)
from instrument.collection import *
# Out:
# I Tue-11:39:00 - ############################################################ startup
# I Tue-11:39:00 - logging started
# I Tue-11:39:00 - logging level = 10
# I Tue-11:39:00 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/collection.py
# I Tue-11:39:00 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/mpl/notebook.py
# Activating auto-logging. Current session state plus future input saved.
# Filename       : /home/beams10/8IDIUSER/.ipython-bluesky/.logs/ipython_console.log
# Mode           : rotate
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# I Tue-11:39:01 - bluesky framework
# I Tue-11:39:01 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/framework/check_python.py
# I Tue-11:39:01 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/framework/check_bluesky.py
# I Tue-11:39:03 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/framework/initialize.py
# I Tue-11:39:06 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/framework/user_dir.py
# I Tue-11:39:06 - User code directory: /home/beams/8IDIUSER/.ipython-bluesky/user
# I Tue-11:39:06 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/framework/metadata.py
# I Tue-11:39:06 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/framework/callbacks.py
# I Tue-11:39:07 - writing to SPEC file: /home/beams10/8IDIUSER/.ipython-bluesky/20200519-113907.dat
# I Tue-11:39:07 -    >>>>   Using default SPEC file name   <<<<
# I Tue-11:39:07 -    file will be created when bluesky ends its next scan
# I Tue-11:39:07 -    to change SPEC file, use command:   newSpecFile('title')
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/aps_source.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/pss.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/foe.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/monochromator.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/be_window.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/actuators.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/attenuators.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/crl.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/detector_stages.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/epid.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/fly.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/lakeshore.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/motors.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/preamps.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/sample_stage.py
# I Tue-11:39:07 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/data_management.py
# I Tue-11:39:08 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/scaler.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/shutters.py
# W Tue-11:39:09 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# W Tue-11:39:09 - Session started when 8_ID-I is not operating.
# W Tue-11:39:09 - Using simulator 'shutter'.
# W Tue-11:39:09 - !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/slits.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/soft_glue_fpga.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/tables.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/lambda_750k.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/rigaku_ufxc.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/plans/alignments.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/plans/flux_calculations.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/plans/functions.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/plans/lineup_tweak.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/plans/move_diodes.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/plans/move_sample.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/plans/pv_registers.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/plans/shutters.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/plans/xpcs_acquire.py
# I Tue-11:39:09 - /home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/utils/explorer.py

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from scipy.optimize import curve_fit

# %%
# %run -m lambda_testing
# Out:
# I Tue-11:39:10 - /home/beams/8IDIUSER/.ipython-bluesky/user/lambda_testing.py

# %%
acq_header = 'A100'
acq_rep = 100
sample_name = 'Silica-D100'


samx_min = -1
samx_max = 1
samx_num = 21

samz_min = -0.5
samz_max = 0.5
samz_num = 11

Temp_list = [26, 28, 29, 30]

# %%
from instrument.devices import samplestage

# %%
print(samplestage.x.position)
print(samplestage.z.position)
lakeshore.loop1.target.get()
# Out:
# 0.0
# 0.0
# 25.0

# %%
scan_header = 'A010'
sample_name = 'Silica_D100'
scans_rep = 100

samx_list = np.linspace(samx_min, samx_max, num=samx_num)
samz_list = np.linspace(samz_min, samz_max, num=samz_num)


def my_way():
    for kk in range(len(Temp_list)):   
        
        yield from bps.mv(
            lakeshore.loop1.target, Temp_list[kk],
            lakeshore.loop1.tolerance, 0.5  
        )
        
        # wait for 200 sec or till temperature stablizes
        yield from lakeshore.loop1.wait_until_settled(timeout=200) 
        
        for ii in range(scans_rep):    
            
            acq_name = f'{scan_header}_{sample_name}_{ii:04}'
            
            yield from bps.mv(
                samplestage.x, samx_list[np.mod(ii,samx_num)],
                samplestage.z, samz_list[int(np.floor(ii/samx_num))]
            )  
            
            print(acq_name)
            
    #         yield from lambda_test(num_iter=1, acquire_time=0.1, acquire_period=0.11, 
    #                 sample_name=acq_name, num_images=2000, sample_suffix="Lq0", analysis_true_false=True)


RE(my_way())
# Out:
# Waiting 0.0s to reach 26.002, now 25.502
# Lakeshore 336 Controller Loop 1 signal: 26.002
# Total time: 0.127s, settled:True
# samplestage_z:   2%|▎                    | 0.00775/0.5 [00:00<00:11, 23.43s/mm]
# samplestage_x:   5%|█▏                      | 0.05/1.0 [00:00<00:03,  4.02s/mm]
# samplestage_z:   4%|▋                    | 0.01785/0.5 [00:00<00:07, 15.75s/mm]
# samplestage_x:   5%|█▏                      | 0.05/1.0 [00:00<00:03,  4.02s/mm]
# samplestage_z:   4%|▋                    | 0.01785/0.5 [00:00<00:07, 15.75s/mm]
# samplestage_x:  10%|██▏                   | 0.1005/1.0 [00:00<00:02,  2.99s/mm]
# samplestage_z:   6%|█▏                   | 0.02945/0.5 [00:00<00:06, 13.50s/mm]
# samplestage_x:  10%|██▏                   | 0.1005/1.0 [00:00<00:02,  2.99s/mm]
# samplestage_z:   6%|█▏                   | 0.02945/0.5 [00:00<00:06, 13.50s/mm]
# samplestage_x:  16%|███▍                  | 0.1585/1.0 [00:00<00:02,  2.63s/mm]
# samplestage_z:   8%|█▌                   | 0.03865/0.5 [00:00<00:05, 12.87s/mm]
# samplestage_x:  16%|███▍                  | 0.1585/1.0 [00:00<00:02,  2.63s/mm]
# samplestage_z:   8%|█▌                   | 0.03865/0.5 [00:00<00:05, 12.87s/mm]
# samplestage_x:  20%|████▍                 | 0.2045/1.0 [00:00<00:02,  2.53s/mm]
# samplestage_z:  10%|██▏                   | 0.0486/0.5 [00:00<00:05, 12.30s/mm]
# samplestage_x:  20%|████▍                 | 0.2045/1.0 [00:00<00:02,  2.53s/mm]
# samplestage_z:  10%|██▏                   | 0.0486/0.5 [00:00<00:05, 12.30s/mm]
# samplestage_x:  25%|█████▎               | 0.25425/1.0 [00:00<00:01,  2.43s/mm]
# samplestage_z:  12%|██▍                  | 0.05865/0.5 [00:00<00:05, 11.89s/mm]
# samplestage_x:  25%|█████▎               | 0.25425/1.0 [00:00<00:01,  2.43s/mm]
# samplestage_z:  12%|██▍                  | 0.05865/0.5 [00:00<00:05, 11.89s/mm]
# samplestage_x:  30%|██████▋               | 0.3045/1.0 [00:00<00:01,  2.36s/mm]
# samplestage_z:  14%|███                   | 0.0686/0.5 [00:00<00:05, 11.65s/mm]
# samplestage_x:  30%|██████▋               | 0.3045/1.0 [00:00<00:01,  2.36s/mm]
# samplestage_z:  14%|███                   | 0.0686/0.5 [00:00<00:05, 11.65s/mm]
# samplestage_x:  35%|███████▍             | 0.35425/1.0 [00:00<00:01,  2.31s/mm]
# samplestage_z:  16%|███▎                 | 0.07855/0.5 [00:00<00:04, 11.43s/mm]
# samplestage_x:  35%|███████▍             | 0.35425/1.0 [00:00<00:01,  2.31s/mm]
# samplestage_z:  16%|███▎                 | 0.07855/0.5 [00:00<00:04, 11.43s/mm]
# samplestage_x:  40%|█████████▎             | 0.404/1.0 [00:00<00:01,  2.27s/mm]
# samplestage_z:  18%|███▋                 | 0.08865/0.5 [00:00<00:04, 11.25s/mm]
# samplestage_x:  40%|█████████▎             | 0.404/1.0 [00:00<00:01,  2.27s/mm]
# samplestage_z:  18%|███▋                 | 0.08865/0.5 [00:00<00:04, 11.25s/mm]
# samplestage_x:  45%|█████████▉            | 0.4545/1.0 [00:01<00:01,  2.24s/mm]
# samplestage_z:  20%|████▎                 | 0.0986/0.5 [00:01<00:04, 11.14s/mm]
# samplestage_x:  45%|█████████▉            | 0.4545/1.0 [00:01<00:01,  2.24s/mm]
# samplestage_z:  20%|████▎                 | 0.0986/0.5 [00:01<00:04, 11.14s/mm]
# samplestage_x:  50%|██████████▌          | 0.50425/1.0 [00:01<00:01,  2.22s/mm]
# samplestage_z:  22%|████▌                | 0.10865/0.5 [00:01<00:04, 11.02s/mm]
# samplestage_x:  50%|██████████▌          | 0.50425/1.0 [00:01<00:01,  2.22s/mm]
# samplestage_z:  22%|████▌                | 0.10865/0.5 [00:01<00:04, 11.02s/mm]
# samplestage_x:  55%|████████████▏         | 0.5545/1.0 [00:01<00:00,  2.20s/mm]
# samplestage_z:  24%|█████▏                | 0.1186/0.5 [00:01<00:04, 10.94s/mm]
# samplestage_x:  55%|████████████▏         | 0.5545/1.0 [00:01<00:00,  2.20s/mm]
# samplestage_z:  24%|█████▏                | 0.1186/0.5 [00:01<00:04, 10.94s/mm]
# samplestage_x:  60%|████████████▋        | 0.60425/1.0 [00:01<00:00,  2.18s/mm]
# samplestage_z:  26%|█████▍               | 0.12855/0.5 [00:01<00:04, 10.87s/mm]
# samplestage_x:  60%|████████████▋        | 0.60425/1.0 [00:01<00:00,  2.18s/mm]
# samplestage_z:  26%|█████▍               | 0.12855/0.5 [00:01<00:04, 10.87s/mm]
# samplestage_x:  65%|███████████████        | 0.654/1.0 [00:01<00:00,  2.17s/mm]
# samplestage_z:  28%|█████▊               | 0.13865/0.5 [00:01<00:03, 10.80s/mm]
# samplestage_x:  65%|███████████████        | 0.654/1.0 [00:01<00:00,  2.17s/mm]
# samplestage_z:  28%|█████▊               | 0.13865/0.5 [00:01<00:03, 10.80s/mm]
# samplestage_x:  70%|███████████████▍      | 0.7045/1.0 [00:01<00:00,  2.15s/mm]
# samplestage_z:  30%|██████▌               | 0.1486/0.5 [00:01<00:03, 10.75s/mm]
# samplestage_x:  70%|███████████████▍      | 0.7045/1.0 [00:01<00:00,  2.15s/mm]
# samplestage_z:  30%|██████▌               | 0.1486/0.5 [00:01<00:03, 10.75s/mm]
# samplestage_x:  75%|███████████████▊     | 0.75425/1.0 [00:01<00:00,  2.14s/mm]
# samplestage_z:  32%|██████▋              | 0.15865/0.5 [00:01<00:03, 10.70s/mm]
# samplestage_x:  75%|███████████████▊     | 0.75425/1.0 [00:01<00:00,  2.14s/mm]
# samplestage_z:  32%|██████▋              | 0.15865/0.5 [00:01<00:03, 10.70s/mm]
# samplestage_x:  80%|█████████████████▋    | 0.8045/1.0 [00:01<00:00,  2.13s/mm]
# samplestage_z:  34%|███████▍              | 0.1686/0.5 [00:01<00:03, 10.67s/mm]
# samplestage_x:  80%|█████████████████▋    | 0.8045/1.0 [00:01<00:00,  2.13s/mm]
# samplestage_z:  34%|███████▍              | 0.1686/0.5 [00:01<00:03, 10.67s/mm]
# samplestage_x:  85%|█████████████████▉   | 0.85425/1.0 [00:01<00:00,  2.13s/mm]
# samplestage_z:  36%|███████▍             | 0.17855/0.5 [00:01<00:03, 10.63s/mm]
# samplestage_x:  85%|█████████████████▉   | 0.85425/1.0 [00:01<00:00,  2.13s/mm]
# samplestage_z:  36%|███████▍             | 0.17855/0.5 [00:01<00:03, 10.63s/mm]
# samplestage_x:  90%|████████████████████▊  | 0.904/1.0 [00:01<00:00,  2.12s/mm]
# samplestage_z:  38%|███████▉             | 0.18865/0.5 [00:01<00:03, 10.59s/mm]
# samplestage_x:  90%|████████████████████▊  | 0.904/1.0 [00:01<00:00,  2.12s/mm]
# samplestage_z:  38%|███████▉             | 0.18865/0.5 [00:01<00:03, 10.59s/mm]
# samplestage_x:  95%|████████████████████▉ | 0.9545/1.0 [00:02<00:00,  2.11s/mm]
# samplestage_z:  40%|████████▋             | 0.1986/0.5 [00:02<00:03, 10.56s/mm]
# samplestage_x:  95%|████████████████████▉ | 0.9545/1.0 [00:02<00:00,  2.11s/mm]
# samplestage_z:  40%|████████▋             | 0.1986/0.5 [00:02<00:03, 10.56s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.12s/mm]
# samplestage_z:  42%|████████▊            | 0.20865/0.5 [00:02<00:03, 10.53s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.12s/mm]
# samplestage_z:  42%|████████▊            | 0.20865/0.5 [00:02<00:03, 10.53s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.22s/mm]
# samplestage_z:  43%|████████▉            | 0.21365/0.5 [00:02<00:03, 10.60s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.22s/mm]
# samplestage_z:  43%|████████▉            | 0.21365/0.5 [00:02<00:03, 10.60s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.32s/mm]
# samplestage_z:  46%|██████████            | 0.2278/0.5 [00:02<00:02, 10.47s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.32s/mm]
# samplestage_z:  46%|██████████            | 0.2278/0.5 [00:02<00:02, 10.47s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.40s/mm]
# samplestage_z:  46%|██████████▋            | 0.232/0.5 [00:02<00:02, 10.59s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.40s/mm]
# samplestage_z:  46%|██████████▋            | 0.232/0.5 [00:02<00:02, 10.59s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.47s/mm]
# samplestage_z:  48%|██████████▏          | 0.24195/0.5 [00:02<00:02, 10.59s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.47s/mm]
# samplestage_z:  48%|██████████▏          | 0.24195/0.5 [00:02<00:02, 10.59s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.57s/mm]
# samplestage_z:  50%|███████████           | 0.2519/0.5 [00:02<00:02, 10.55s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.57s/mm]
# samplestage_z:  50%|███████████           | 0.2519/0.5 [00:02<00:02, 10.55s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.67s/mm]
# samplestage_z:  52%|███████████          | 0.26195/0.5 [00:02<00:02, 10.54s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.67s/mm]
# samplestage_z:  52%|███████████          | 0.26195/0.5 [00:02<00:02, 10.54s/mm]
# samplestage_x: 100%|█████████████████████████| 1.0/1.0 [00:02<00:00,  2.80s/mm]
# samplestage_z:  52%|███████████          | 0.26195/0.5 [00:02<00:02, 10.54s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  54%|███████████▍         | 0.27215/0.5 [00:02<00:02, 10.50s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  56%|████████████▏         | 0.2779/0.5 [00:02<00:02, 10.38s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  58%|████████████         | 0.28785/0.5 [00:02<00:02, 10.36s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  60%|█████████████         | 0.2978/0.5 [00:03<00:02, 10.35s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  62%|████████████▉        | 0.30775/0.5 [00:03<00:01, 10.34s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  64%|█████████████▎       | 0.31785/0.5 [00:03<00:01, 10.32s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  66%|███████████████        | 0.328/0.5 [00:03<00:01, 10.32s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  68%|██████████████▏      | 0.33785/0.5 [00:03<00:01, 10.30s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  70%|███████████████▎      | 0.3477/0.5 [00:03<00:01, 10.30s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  72%|███████████████      | 0.35775/0.5 [00:03<00:01, 10.29s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  74%|███████████████▍     | 0.36785/0.5 [00:03<00:01, 10.28s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  76%|████████████████▋     | 0.3779/0.5 [00:03<00:01, 10.28s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  78%|████████████████▎    | 0.38785/0.5 [00:03<00:01, 10.26s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  80%|█████████████████▍    | 0.3977/0.5 [00:04<00:01, 10.26s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  82%|█████████████████▏   | 0.40775/0.5 [00:04<00:00, 10.25s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  84%|█████████████████▌   | 0.41785/0.5 [00:04<00:00, 10.25s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  86%|███████████████████▋   | 0.428/0.5 [00:04<00:00, 10.24s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  88%|██████████████████▍  | 0.43785/0.5 [00:04<00:00, 10.24s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  90%|███████████████████▋  | 0.4478/0.5 [00:04<00:00, 10.23s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  92%|███████████████████▏ | 0.45775/0.5 [00:04<00:00, 10.23s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  94%|███████████████████▋ | 0.46785/0.5 [00:04<00:00, 10.22s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  96%|█████████████████████ | 0.4779/0.5 [00:04<00:00, 10.22s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z:  98%|████████████████████▍| 0.48785/0.5 [00:04<00:00, 10.21s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z: 100%|█████████████████████▉| 0.4978/0.5 [00:05<00:00, 10.21s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z: 100%|█████████████████████████| 0.5/0.5 [00:05<00:00, 10.36s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z: 100%|█████████████████████████| 0.5/0.5 [00:05<00:00, 10.56s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z: 100%|█████████████████████████| 0.5/0.5 [00:05<00:00, 10.83s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z: 100%|█████████████████████████| 0.5/0.5 [00:05<00:00, 10.96s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z: 100%|█████████████████████████| 0.5/0.5 [00:05<00:00, 11.03s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z: 100%|█████████████████████████| 0.5/0.5 [00:05<00:00, 11.23s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z: 100%|█████████████████████████| 0.5/0.5 [00:05<00:00, 11.43s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z: 100%|█████████████████████████| 0.5/0.5 [00:05<00:00, 11.63s/mm]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  23%|█████▎                 | 0.023/0.1 [00:00<00:00,  6.47s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.65s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  54%|███████████▍         | 0.05425/0.1 [00:00<00:00,  6.44s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  57%|████████████         | 0.05725/0.1 [00:00<00:00,  6.67s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  70%|██████████████▋      | 0.06975/0.1 [00:00<00:00,  6.92s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  83%|█████████████████▍   | 0.08275/0.1 [00:00<00:00,  7.04s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  95%|█████████████████████▊ | 0.095/0.1 [00:00<00:00,  7.18s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.66s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  23%|█████▎                 | 0.023/0.1 [00:00<00:00,  6.56s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.69s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.88s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  57%|████████████         | 0.05725/0.1 [00:00<00:00,  6.70s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  70%|██████████████▋      | 0.06975/0.1 [00:00<00:00,  6.95s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  82%|██████████████████▏   | 0.0825/0.1 [00:00<00:00,  7.09s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  95%|█████████████████████▊ | 0.095/0.1 [00:00<00:00,  7.20s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.72s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  21%|████▎                | 0.02075/0.1 [00:00<00:00,  7.67s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.59s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  7.04s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  58%|████████████▊         | 0.0585/0.1 [00:00<00:00,  6.49s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  71%|████████████████▎      | 0.071/0.1 [00:00<00:00,  6.79s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  84%|██████████████████▎   | 0.0835/0.1 [00:00<00:00,  6.93s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  96%|████████████████████ | 0.09575/0.1 [00:00<00:00,  7.10s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.63s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  22%|████▌                | 0.02175/0.1 [00:00<00:00,  6.10s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.65s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.51s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  6.92s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.12s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.26s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|███████████████████▍ | 0.09275/0.1 [00:00<00:00,  7.36s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.79s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  23%|████▉                | 0.02325/0.1 [00:00<00:00,  5.87s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.73s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.59s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|████████████▏         | 0.0555/0.1 [00:00<00:00,  6.96s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.17s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.30s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.38s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.83s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  24%|█████▍                | 0.0245/0.1 [00:00<00:00,  5.55s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.71s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.54s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|████████████▏         | 0.0555/0.1 [00:00<00:00,  6.94s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.16s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.30s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.37s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.81s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  24%|█████▌                 | 0.024/0.1 [00:00<00:00,  5.77s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.77s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▎          | 0.0515/0.1 [00:00<00:00,  6.58s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  7.03s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.21s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.33s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|███████████████████▍ | 0.09275/0.1 [00:00<00:00,  7.42s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.86s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  22%|████▌                | 0.02175/0.1 [00:00<00:00,  6.05s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.64s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  7.08s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  58%|████████████▊         | 0.0585/0.1 [00:00<00:00,  6.54s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  71%|████████████████▎      | 0.071/0.1 [00:00<00:00,  6.79s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  84%|█████████████████▌   | 0.08375/0.1 [00:00<00:00,  6.94s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  96%|████████████████████ | 0.09575/0.1 [00:00<00:00,  7.12s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.65s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  22%|████▌                | 0.02175/0.1 [00:00<00:00,  6.10s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.65s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.52s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  6.93s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.12s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.26s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.34s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.85s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  21%|████▋                 | 0.0215/0.1 [00:00<00:00,  6.06s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.60s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.43s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|████████████▏         | 0.0555/0.1 [00:00<00:00,  6.85s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.08s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.26s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.31s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.77s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  22%|████▋                | 0.02225/0.1 [00:00<00:00,  6.00s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.67s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.50s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|████████████▏         | 0.0555/0.1 [00:00<00:00,  6.90s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.13s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.26s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.34s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.78s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  23%|████▉                | 0.02325/0.1 [00:00<00:00,  5.85s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.72s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.58s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  6.98s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.17s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.30s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|███████████████████▍ | 0.09275/0.1 [00:00<00:00,  7.39s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.84s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  22%|████▋                | 0.02225/0.1 [00:00<00:00,  5.96s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.65s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.52s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  6.98s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|███████████████▋       | 0.068/0.1 [00:00<00:00,  7.10s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.26s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|███████████████████▍ | 0.09275/0.1 [00:00<00:00,  7.36s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.78s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  22%|████▌                | 0.02175/0.1 [00:00<00:00,  6.06s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.63s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.47s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  6.91s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.11s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.25s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.34s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.79s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  23%|████▉                | 0.02325/0.1 [00:00<00:00,  5.80s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.70s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.53s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|████████████▏         | 0.0555/0.1 [00:00<00:00,  6.93s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.15s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.29s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.37s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.82s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  23%|████▉                | 0.02325/0.1 [00:00<00:00,  5.84s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.72s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.55s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|████████████▏         | 0.0555/0.1 [00:00<00:00,  7.00s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.17s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.30s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.37s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.81s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  23%|████▉                | 0.02325/0.1 [00:00<00:00,  5.85s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.73s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.58s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  6.98s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.17s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.30s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|███████████████████▍ | 0.09275/0.1 [00:00<00:00,  7.40s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.90s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  21%|████▎                | 0.02075/0.1 [00:00<00:00,  6.20s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.59s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.44s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  6.86s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|███████████████▋       | 0.068/0.1 [00:00<00:00,  7.05s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.22s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|███████████████████▍ | 0.09275/0.1 [00:00<00:00,  7.32s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.75s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  23%|████▉                | 0.02325/0.1 [00:00<00:00,  5.81s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.70s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.53s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  6.97s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.16s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.29s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.37s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.83s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  23%|█████▎                 | 0.023/0.1 [00:00<00:00,  5.85s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.68s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.52s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|████████████▏         | 0.0555/0.1 [00:00<00:00,  6.92s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.14s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.28s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.35s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.81s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:   2%|▍                     | 0.0385/2.0 [00:00<00:10,  5.28s/mm]
# samplestage_z:   5%|█▏                   | 0.00545/0.1 [00:00<00:03, 33.56s/mm]
# samplestage_x:   2%|▍                     | 0.0385/2.0 [00:00<00:10,  5.28s/mm]
# samplestage_z:  15%|███▏                 | 0.01535/0.1 [00:00<00:01, 18.41s/mm]
# samplestage_x:   4%|▉                    | 0.08825/2.0 [00:00<00:06,  3.44s/mm]
# samplestage_z:  15%|███▏                 | 0.01535/0.1 [00:00<00:01, 18.41s/mm]
# samplestage_x:   4%|▉                    | 0.08825/2.0 [00:00<00:06,  3.44s/mm]
# samplestage_z:  25%|█████▌                | 0.0254/0.1 [00:00<00:01, 15.05s/mm]
# samplestage_x:   7%|█▌                    | 0.1385/2.0 [00:00<00:05,  2.92s/mm]
# samplestage_z:  25%|█████▌                | 0.0254/0.1 [00:00<00:01, 15.05s/mm]
# samplestage_x:   7%|█▌                    | 0.1385/2.0 [00:00<00:05,  2.92s/mm]
# samplestage_z:  35%|███████▍             | 0.03535/0.1 [00:00<00:00, 13.65s/mm]
# samplestage_x:   9%|█▉                   | 0.18825/2.0 [00:00<00:04,  2.67s/mm]
# samplestage_z:  35%|███████▍             | 0.03535/0.1 [00:00<00:00, 13.65s/mm]
# samplestage_x:   9%|█▉                   | 0.18825/2.0 [00:00<00:04,  2.67s/mm]
# samplestage_z:  45%|█████████▉            | 0.0453/0.1 [00:00<00:00, 12.85s/mm]
# ...
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.81s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  18%|███▋                 | 0.01775/0.1 [00:00<00:00,  7.06s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.61s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  54%|███████████▍         | 0.05425/0.1 [00:00<00:00,  7.02s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  67%|██████████████       | 0.06675/0.1 [00:00<00:00,  7.21s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  79%|████████████████▋    | 0.07925/0.1 [00:00<00:00,  7.34s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  92%|███████████████████▎ | 0.09225/0.1 [00:00<00:00,  7.38s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.81s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  24%|████▉                | 0.02375/0.1 [00:00<00:00,  5.79s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.75s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.62s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  7.02s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.20s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.32s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|███████████████████▍ | 0.09275/0.1 [00:00<00:00,  7.41s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.82s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  24%|█████▌                 | 0.024/0.1 [00:00<00:00,  5.69s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.73s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.56s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|████████████▏         | 0.0555/0.1 [00:00<00:00,  6.99s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|███████████████▋       | 0.068/0.1 [00:00<00:00,  7.16s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.31s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.38s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.79s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  18%|███▊                 | 0.01825/0.1 [00:00<00:00,  6.86s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.68s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  54%|███████████▍         | 0.05425/0.1 [00:00<00:00,  7.05s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  67%|██████████████       | 0.06675/0.1 [00:00<00:00,  7.24s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  79%|████████████████▋    | 0.07925/0.1 [00:00<00:00,  7.39s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  92%|███████████████████▎ | 0.09175/0.1 [00:00<00:00,  7.46s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.84s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  18%|████                  | 0.0185/0.1 [00:00<00:00,  6.62s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.63s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  54%|███████████▍         | 0.05425/0.1 [00:00<00:00,  7.04s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  67%|███████████████▍       | 0.067/0.1 [00:00<00:00,  7.19s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  79%|████████████████▋    | 0.07925/0.1 [00:00<00:00,  7.34s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  92%|███████████████████▎ | 0.09175/0.1 [00:00<00:00,  7.43s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.83s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  18%|████                  | 0.0185/0.1 [00:00<00:00,  6.79s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.63s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  54%|███████████▍         | 0.05425/0.1 [00:00<00:00,  7.02s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  67%|██████████████       | 0.06675/0.1 [00:00<00:00,  7.21s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  79%|████████████████▋    | 0.07925/0.1 [00:00<00:00,  7.34s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  92%|███████████████████▎ | 0.09225/0.1 [00:00<00:00,  7.38s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.82s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_x:  24%|████▉                | 0.02375/0.1 [00:00<00:00,  5.82s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.77s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|███████████▋           | 0.051/0.1 [00:00<00:00,  6.63s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|███████████▌         | 0.05525/0.1 [00:00<00:00,  7.03s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|██████████████▏      | 0.06775/0.1 [00:00<00:00,  7.20s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.33s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|███████████████████▍ | 0.09275/0.1 [00:00<00:00,  7.42s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.82s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
# samplestage_z [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  24%|█████▌                 | 0.024/0.1 [00:00<00:00,  5.70s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.74s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  51%|██████████▊          | 0.05125/0.1 [00:00<00:00,  6.57s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  55%|████████████▏         | 0.0555/0.1 [00:00<00:00,  7.00s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  68%|███████████████▋       | 0.068/0.1 [00:00<00:00,  7.16s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  80%|████████████████▊    | 0.08025/0.1 [00:00<00:00,  7.32s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  93%|█████████████████████▍ | 0.093/0.1 [00:00<00:00,  7.38s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.79s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  19%|████                 | 0.01925/0.1 [00:00<00:00,  6.59s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  50%|████████████            | 0.05/0.1 [00:00<00:00,  5.72s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  54%|███████████▍         | 0.05425/0.1 [00:00<00:00,  7.11s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  67%|██████████████       | 0.06675/0.1 [00:00<00:00,  7.27s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  79%|████████████████▋    | 0.07925/0.1 [00:00<00:00,  7.40s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x:  92%|███████████████████▎ | 0.09175/0.1 [00:00<00:00,  7.48s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x: 100%|█████████████████████████| 0.1/0.1 [00:00<00:00,  7.87s/mm]
# samplestage_z [In progress. No progress bar available.]
# samplestage_x [In progress. No progress bar available.]
#
#
# A010_Silica_D100_0100
# Waiting 0.0s to reach 28.002, now 26.052
# Waiting 5.0s to reach 28.002, now 26.092
# Waiting 10.0s to reach 28.002, now 26.182
# Waiting 15.0s to reach 28.002, now 26.282
# Waiting 20.0s to reach 28.002, now 26.392
# Waiting 25.0s to reach 28.002, now 26.512
# A 'deferred pause' has been requested. The RunEngine will pause at the next checkpoint. To pause immediately, hit Ctrl+C again in the next 10 seconds.Deferred pause acknowledged. Continuing to checkpoint.
#
# Waiting 30.0s to reach 28.002, now 26.622
# Waiting 35.0s to reach 28.002, now 26.732
# A 'deferred pause' has been requested. The RunEngine will pause at the next checkpoint. To pause immediately, hit Ctrl+C again in the next 10 seconds.
# Deferred pause acknowledged. Continuing to checkpoint.
# Waiting 40.0s to reach 28.002, now 26.842
# trying a second time
# Pausing...
# ---------------------------------------------------------------------------
# RunEngineInterrupted                      Traceback (most recent call last)
# <ipython-input-13-4def49915a21> in <module>
#      33
#      34
# ---> 35 RE(my_way())
#      36
#
# ~/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     798
#     799         if self._interrupted:
# --> 800             raise RunEngineInterrupted(self.pause_msg) from None
#     801
#     802         return tuple(self._run_start_uids)
#
# RunEngineInterrupted:
# Your RunEngine is entering a paused state. These are your options for changing
# the state of the RunEngine:
#
# RE.resume()    Resume the plan.
# RE.abort()     Perform cleanup, then kill plan. Mark exit_stats='aborted'.
# RE.stop()      Perform cleanup, then kill plan. Mark exit_status='success'.
# RE.halt()      Emergency Stop: Do not perform cleanup --- just stop.

# %%
RE.abort()
# Out:
# Run aborted
# Traceback (most recent call last):
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/run_engine.py", line 1332, in _run
#     stashed_exception or resp)
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 1307, in __call__
#     return (yield from plan)
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 1162, in baseline_wrapper
#     return (yield from plan_mutator(plan, insert_baseline))
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 78, in plan_mutator
#     msg = plan_stack[-1].throw(exception)
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 803, in monitor_during_wrapper
#     return (yield from plan2)
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 78, in plan_mutator
#     msg = plan_stack[-1].throw(exception)
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 78, in plan_mutator
#     msg = plan_stack[-1].throw(exception)
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 861, in fly_during_wrapper
#     return (yield from plan2)
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 78, in plan_mutator
#     msg = plan_stack[-1].throw(exception)
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 78, in plan_mutator
#     msg = plan_stack[-1].throw(exception)
#   File "<ipython-input-13-4def49915a21>", line 20, in my_way
#     yield from lakeshore.loop1.wait_until_settled(timeout=200)
#   File "/home/beams/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/devices/lakeshore.py", line 89, in wait_until_settled
#     yield from bps.sleep(self.poll_s)
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/plan_stubs.py", line 452, in sleep
#     return (yield Msg('sleep', None, time))
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 195, in plan_mutator
#     inner_ret = yield msg
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 195, in plan_mutator
#     inner_ret = yield msg
#   File "/home/beams/8IDIUSER/.conda/envs/bluesky_2020_5/lib/python3.7/site-packages/bluesky/preprocessors.py", line 195, in plan_mutator
#     inner_ret = yield msg
#   [Previous line repeated 2 more times]
# bluesky.utils.RequestAbort
# Aborting: running cleanup and marking exit_status as 'abort'...
# ()
