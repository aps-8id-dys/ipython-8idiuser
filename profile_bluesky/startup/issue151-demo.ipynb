# %%
from instrument.collection import *
# Out:
# I Mon-14:31:33 - ############################################################ startup
# I Mon-14:31:33 - logging started
# I Mon-14:31:33 - logging level = 10
# I Mon-14:31:33 - /home/beams10/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/collection.py
# I Mon-14:31:33 - /home/beams10/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/mpl/notebook.py
# Activating auto-logging. Current session state plus future input saved.
# Filename       : /home/beams10/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/.logs/ipython_console.log
# Mode           : rotate
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# I Mon-14:31:37 - bluesky framework
# I Mon-14:31:37 - /home/beams10/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/framework/check_python.py
# I Mon-14:31:38 - /home/beams10/8IDIUSER/.ipython-bluesky/profile_bluesky/startup/instrument/framework/initialize.py
# ...

# %%
show_ophyd_symbols()
# Out:
# ================ ================================ =============================== =================
# name             ophyd structure                  EPICS PV                        label(s)
# ================ ================================ =============================== =================
# Atten1           EpicsSignalRO                    8idi:userTran1.P                detectors
# Atten2           EpicsSignalRO                    8idi:userTran3.P                detectors
# I0Mon            EpicsSignalRO                    8idi:scaler1.S8                 channel counter
# I_APS            EpicsSignalRO                    8idi:scaler1.S7                 channel counter
# T_A              EpicsSignalRO                    8idi:LS336:TC4:IN1
# T_SET            EpicsSignal                      8idi:LS336:TC4:OUT1:SP
# WBslit           WBslitDevice
# actuator_flux    EpicsSignal                      8idi:9440:1:bo_0                actuator
# ...

# %%
object_explorer(pid1)
# Out:
# ============================= ============== ==========================
# name                          PV reference   value
# ============================= ============== ==========================
# alarm_hysteresis              8idi:pid1.HYST 0.0
# alarm_severity                8idi:pid1.SEVR 0
# alarm_status                  8idi:pid1.STAT 0
# calculated_D                  8idi:pid1.D    0.0
# calculated_I                  8idi:pid1.I    0.6591783130816433
# calculated_P                  8idi:pid1.P    -20.555999999999997
# controlled_value              8idi:pid1.CVAL 22.278
# controlled_value_link         8idi:pid1.INP  8idi:LS336:TC4:IN3 NPP NMS
# derivative_gain               8idi:pid1.KD   0.0
# description                   8idi:pid1.DESC
# device_type                   8idi:pid1.DTYP 0
# disable_alarm_severity        8idi:pid1.DISS 0
# disable_value                 8idi:pid1.DISV 1
# feedback_on                   8idi:pid1.FBON 0
# ...

# %%
object_explorer(samplestage)
# Out:
# ============================ =============== ===================
# name                         PV reference    value
# ============================ =============== ===================
# chi.acceleration             8idi:m53.ACCL   0.2
# chi.direction_of_travel      8idi:m53.TDIR   1
# chi.high_limit_switch        8idi:m53.HLS    0
# chi.home_forward             8idi:m53.HOMF   0
# chi.home_reverse             8idi:m53.HOMR   0
# chi.low_limit_switch         8idi:m53.LLS    0
# chi.motor_done_move          8idi:m53.DMOV   1
# chi.motor_egu                8idi:m53.EGU    deg
# chi.motor_is_moving          8idi:m53.MOVN   0
# chi.motor_stop               8idi:m53.STOP   0
# chi.offset_freeze_switch     8idi:m53.FOFF   0
# chi.set_use_switch           8idi:m53.SET    0
# chi.user_offset              8idi:m53.OFF    -5.1675
# chi.user_offset_dir          8idi:m53.DIR    0
# chi.user_readback            8idi:m53.RBV    0.0
# chi.user_setpoint            8idi:m53.VAL    0.0
# ...

# %%
# Out:
# | name                         | PV reference    | value               |
# | ---------------------------- | --------------- | ------------------- |
# | chi.acceleration             | 8idi:m53.ACCL   | 0.2                 |
# | chi.direction_of_travel      | 8idi:m53.TDIR   | 1                   |
# | chi.high_limit_switch        | 8idi:m53.HLS    | 0                   |
# | chi.home_forward             | 8idi:m53.HOMF   | 0                   |
# | chi.home_reverse             | 8idi:m53.HOMR   | 0                   |
# | chi.low_limit_switch         | 8idi:m53.LLS    | 0                   |
# | chi.motor_done_move          | 8idi:m53.DMOV   | 1                   |
# | chi.motor_egu                | 8idi:m53.EGU    | deg                 |
# | chi.motor_is_moving          | 8idi:m53.MOVN   | 0                   |
# | chi.motor_stop               | 8idi:m53.STOP   | 0                   |
# | chi.offset_freeze_switch     | 8idi:m53.FOFF   | 0                   |
# ...
